# %%
#importando os filmes vistos em 2025 e iterando sobre eles
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('movies_watched.csv', skipinitialspace=True)

print(df)
print(f"\nTotal de filmes assistidos:  {len(df)}")
print(f"Minha nota média: {df['personal_rating'].mean():.2f}")
# Out:
#                               title  launching_year  personal_rating
# 0                          Superman            2025              9.0
# 1   The Fantastic Four: First Steps            2025              7.0
# 2               A Walk in the Woods            2015              7.0
# 3               Million Dollar Baby            2004              9.0
# 4                  American Fiction            2023              9.0
# 5                    The Apprentice            2024              8.8
# 6                   Of Mice and Men            1992              7.5
# 7                          Conclave            2024              8.9
# 8                        Green Book            2018              9.0
# 9                   American Sniper            2014              8.7
# 10                 Scent of a Woman            1992              8.0
# 11                              Big            1988              8.8
# 12                  The Company Men            2010              7.0
# ...
